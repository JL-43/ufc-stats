# %%
# import string
import pandas as pd

# %%
# alphabet = string.ascii_lowercase

# %%
# for letter in alphabet:
#   ufc_stats = f'http://ufcstats.com/statistics/fighters?char={letter}&page=all'
#   if letter == 'a':
#     df = pd.read_html(ufc_stats)[0]
#   else:
#     temp_df = pd.read_html(ufc_stats)[0]
#     df = pd.concat([df, temp_df])

# %%
ufc_stats = 'http://ufcstats.com/statistics/fighters?char=*&page=all'
df = pd.read_html(ufc_stats)[0]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#         First      Last      Nickname     Ht.       Wt.  Reach    Stance  \
# 0         NaN       NaN           NaN     NaN       NaN    NaN       NaN
# 1         Tom     Aaron           NaN      --  155 lbs.     --       NaN
# 2       Danny    Abbadi  The Assassin  5' 11"  155 lbs.     --  Orthodox
# 3     Nariman   Abbasov           NaN   5' 8"  155 lbs.     --       NaN
# 4       David    Abbott          Tank   6' 0"  265 lbs.     --    Switch
# ...       ...       ...           ...     ...       ...    ...       ...
# 3872     Dave  Zitanick           NaN      --  170 lbs.     --       NaN
# 3873     Alex    Zuniga           NaN      --  145 lbs.     --       NaN
# 3874   George    Zuniga           NaN   5' 9"  185 lbs.     --       NaN
# 3875    Allan    Zuniga         Tigre   5' 7"  155 lbs.  70.0"  Orthodox
# 3876   Virgil   Zwicker        RezDog   6' 2"  205 lbs.  74.0"       NaN
#
#          W     L    D  Belt
# 0      NaN   NaN  NaN   NaN
# 1      5.0   3.0  0.0   NaN
# ...

# %%
df.to_csv('1_ufc_fighters_scraped.csv', index=False)
